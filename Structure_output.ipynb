# %% [markdown]
# **A Structured Output Agent in LangChain (or other LLM frameworks) refers to an agent that produces responses in a specific structured format, such as JSON, dictionaries, or other structured data types. These agents are particularly useful when you want to ensure that your responses conform to a defined schema, making it easier to parse, validate, and utilize in downstream applications.**
#
# #### Why Use a Structured Output Agent?
#
# - Controlled Responses: Ensures that the outputs follow a specific format, reducing ambiguity.
# - Data Validation: Useful when you want the model output to fit predefined structures, like for APIs or database entries.
# - Automation: Makes integration with systems like dashboards, ETL pipelines, or business workflows easier.

# %%
from langchain_community.tools.tavily_search import TavilySearchResults 
from langchain_core.tools import tool
from pydantic import BaseModel, Field
from langgraph.graph import MessagesState, StateGraph, END 
from langgraph.prebuilt import ToolNode 
from langchain_core.messages import HumanMessage

# %%
from langchain_openai import ChatOpenAI 
llm = ChatOpenAI()

# %%
tavily_tool = TavilySearchResults()

# %%
@tool 
def get_city_details(prompt):
    "Should do a web search to find the required city details"
    response = tavily_tool.invoke(prompt)
    return response

# %%
tools = [get_city_details]

# %%
model_with_tools = llm.bind_tools(tools)

# %% [markdown]
# **The BaseModel class is a core component of Pydantic, which is used extensively in Python applications for data validation, type checking, and parsing. It's particularly useful when working with APIs, web frameworks like FastAPI, and other scenarios where you need to enforce data structure and ensure data integrity.**
#
# Here's an overview of the BaseModel class, along with some examples to demonstrate how you can use it effectively.
#
# This code defines a Pydantic model called CityDetails using the BaseModel class. Let's break it down:
#
# - Explanation:
#
# 1. Class Definition:
#
# 2. CityDetails inherits from BaseModel, making it a data validation model.
#
# 3. Fields with Type Annotations:
#
# 4. state_name: A string representing the state name of a city.
#
# 5. state_capital: A string representing the capital of that state.
#
# 6. country_name: A string representing the country name where the city is located.
#
# 7. country_capital: A string representing the capital of that country.
#
# **Field Descriptions:**
#
# - Each field uses Field() to provide a description that helps clarify what information each attribute represents.
#
# **Purpose:**
# - The model validates and structures data related to cities.
# - Useful for ensuring that any data related to cities has the correct structure before processing.
# - Helpful in APIs (like FastAPI) to generate self-documenting endpoints.

# %%
class CityDetails(BaseModel):
    """Respond to the user with this"""
    state_name : str = Field(description="State name of the city")
    state_capital : str = Field(description="State capital of the city")
    country_name : str = Field(description="Country name of the city")
    country_capital : str = Field(description="Coutry capital of the city")

# %%
# Inherit 'messages' key from MessagesState, which is a list of chat messages
class AgentState(MessagesState):
    # Final structured response from the agent
    final_response : CityDetails

# %%
model_with_structured_output = llm.with_structured_output(CityDetails)

# %%
def call_model(state : AgentState):
    print(f" this is 01 input from call model {state}")
    response = model_with_tools.invoke(state['messages'])
    print(f" this is 02 response from call model {response}")
    return {"messages" : [response]}

# %%
def should_continue(state: AgentState):
    messages = state["messages"]
    last_message = messages[-1]
    
    # If there is no function call, then we respond to the user
    if not last_message.tool_calls:
        return "respond"
    # Otherwise if there is, we continue with the tool
    else:
        return "continue"

# %%
def respond(state: AgentState):
    print(f"here is 03 state from respond {state}")
    response = model_with_structured_output.invoke([HumanMessage(content=state['messages'][-1].content)])
    # We return the final answer
    print(f"this is 04 response from respond{response}")
    return {"final_response": response}

# %%
# Define a new graph
workflow = StateGraph(AgentState)

# Define the two nodes we will cycle between
workflow.add_node("llm", call_model)
workflow.add_node("tools", ToolNode(tools))
workflow.add_node("respond", respond)

# Set the entrypoint as `agent`
# This means that this node is the first one called
workflow.set_entry_point("llm")

# We now add a conditional edge
workflow.add_conditional_edges(
    "llm",
    
    should_continue,
    {
        "continue": "tools",
        "respond": "respond",
    },
)

workflow.add_edge("tools", "llm")
workflow.add_edge("respond", END)
graph = workflow.compile()

# %%
from IPython.display import Image, display
# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
answer = graph.invoke(input={"messages": [("human", "Tell me about the city details for Mumbai?")]})['final_response']
# Out:
#  this is 01 input from call model {'messages': [HumanMessage(content='Tell me about the city details for Mumbai?', additional_kwargs={}, response_metadata={}, id='f11e5482-03bf-47bb-94b5-5a6d0a35e1be')], 'final_response': None}
#  this is 02 response from call model content='' additional_kwargs={'tool_calls': [{'id': 'call_CA7Ayy2IPuQgztsMYG1LR6tt', 'function': {'arguments': '{"prompt":"Mumbai"}', 'name': 'get_city_details'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 60, 'total_tokens': 76, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None} id='run-27b58312-4dcb-4729-9f10-6bff9e946018-0' tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'Mumbai'}, 'id': 'call_CA7Ayy2IPuQgztsMYG1LR6tt', 'type': 'tool_call'}] usage_metadata={'input_tokens': 60, 'output_tokens': 16, 'total_tokens': 76, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
#  this is 01 input from call model {'messages': [HumanMessage(content='Tell me about the city details for Mumbai?', additional_kwargs={}, response_metadata={}, id='f11e5482-03bf-47bb-94b5-5a6d0a35e1be'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_CA7Ayy2IPuQgztsMYG1LR6tt', 'function': {'arguments': '{"prompt":"Mumbai"}', 'name': 'get_city_details'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 60, 'total_tokens': 76, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-27b58312-4dcb-4729-9f10-6bff9e946018-0', tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'Mumbai'}, 'id': 'call_CA7Ayy2IPuQgztsMYG1LR6tt', 'type': 'tool_call'}], usage_metadata={'input_tokens': 60, 'output_tokens': 16, 'total_tokens': 76, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"url": "https://www.tripadvisor.com/Attractions-g304554-Activities-Mumbai_Maharashtra.html", "content": "Things to Do in Mumbai, India: See Tripadvisor\'s 641,172 traveler reviews and photos of Mumbai tourist attractions. Find what to do today, this weekend, or in December. We have reviews of the best places to see in Mumbai. Visit top-rated & must-see attractions."}, {"url": "https://www.tripsavvy.com/mumbai-attractions-and-places-to-visit-1539804", "content": "Top 12 Attractions and Places to Visit in Mumbai\\nOne Week in Mumbai: The Perfect Itinerary\\n15 Iconic Mumbai Religious Places to Visit\\nTop 18 Things to Do in Mumbai\\n48 Hours in Mumbai: The Perfect Itinerary\\n101 Places to Visit in Mumbai\\nThe 9 Top Parks in Mumbai\\n14 Best Mumbai Markets for Shopping and Sightseeing\\n15 Best Mumbai Tours to Really Get to Know the City\\n8 Cool Neighborhoods to Explore in Mumbai\\n11 Free Things to Do in India\\n20 Landmarks that Showcase Mumbai\'s Architecture\\nThe Best Time to Visit Mumbai\\nThe 9 Top Things to Do in Mumbai\'s Fort Neighborhood\\nEssential Guide to Walking Tours in India\\n10 Places to Marvel Over Mumbai\'s Unique Infrastructure\\n22 Caves in India for History, Adventure and Spirituality If these attractions aren\'t enough for you, check out these 101 Places to Visit in Mumbai!\\nGateway of India\\nVatsal Shah / TripSavvy\\nMumbai\'s most recognized monument, the Gateway of India, was constructed in 1924 to commemorate the visit of King George V and Queen Mary to the city. Some of the best are the Gothic-looking Chhatrapati Shivaji Maharaj Vastu Sangrahalaya Museum (formerly known as the Prince of Wales Museum), the Kala Ghoda art precinct, Chhatrapati Shivaji Maharaj Terminus (formerly Victoria Terminus) railway station, the Bombay High Court and the buildings of Horniman Circle in the Fort area. Juhu and Marine Drive Chowpatty Beaches\\nVatsal Shah / TripSavvy\\nAt the end of a tiring day of sightseeing, relax with the locals on the beaches of Juhu and Marine Drive, and watch the sunset. Mumbai Dabbawalas\\nDabbawala, meaning a person who carries a container, is the term given to the thousands of men responsible for transporting and delivering around 200,000 lunch boxes of freshly cooked food to the city\'s office workers every day."}, {"url": "https://www.tripsavvy.com/best-things-to-do-in-mumbai-5070679", "content": "Top 18 Things to Do in Mumbai\\nTop 12 Attractions and Places to Visit in Mumbai\\n9 Best Luxury Day Spas in Mumbai to Relax and Rejuvenate\\nOne Week in Mumbai: The Perfect Itinerary\\n48 Hours in Mumbai: The Perfect Itinerary\\nThe 9 Top Parks in Mumbai\\n8 Cool Neighborhoods to Explore in Mumbai\\n101 Places to Visit in Mumbai\\n20 Landmarks that Showcase Mumbai\'s Architecture\\n ...
#  this is 02 response from call model content="Here are some details about Mumbai:\n\n1. [Tripadvisor](https://www.tripadvisor.com/Attractions-g304554-Activities-Mumbai_Maharashtra.html): Things to Do in Mumbai, India: See Tripadvisor's 641,172 traveler reviews and photos of Mumbai tourist attractions. Find what to do today, this weekend, or in December. Visit top-rated & must-see attractions.\n\n2. [Tripsavvy](https://www.tripsavvy.com/mumbai-attractions-and-places-to-visit-1539804): Mumbai's most recognized monument is the Gateway of India, constructed in 1924 to commemorate the visit of King George V and Queen Mary to the city. Other attractions include Juhu and Marine Drive Chowpatty Beaches, Mumbai Dabbawalas, and more.\n\n3. [Tripsavvy](https://www.tripsavvy.com/best-things-to-do-in-mumbai-5070679): Mumbai offers a variety of attractions and activities, including exploring the Celebrated Dabbawalas, walking around Holy Banganga Tank, and uncovering the past at a museum like Chhatrapati Shivaji Maharaj Vastu Sangrahalaya.\n\n4. [Wikipedia](https://en.wikipedia.org/wiki/Mumbai): Mumbai, also known as Bombay, is the richest Indian city and one of the richest cities in the world. It is home to the seventh-highest number of billionaires and has a population of 12,442,373 as per the 2011 census.\n\n5. [Britannica](https://www.britannica.com/place/Mumbai): Mumbai occupies a peninsular site on Bombay Island and has a rich history dating back to ancient settlements. The city grew around the 17th-century British fortifications in the area known as the Fort, which is now occupied by public and commercial offices.\n\nThese sources provide a wealth of information about Mumbai, its attractions, history, and infrastructure." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 408, 'prompt_tokens': 2545, 'total_tokens': 2953, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-ec5f2552-2705-402c-95c3-169621d45868-0' usage_metadata={'input_tokens': 2545, 'output_tokens': 408, 'total_tokens': 2953, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# here is 03 state from respond {'messages': [HumanMessage(content='Tell me about the city details for Mumbai?', additional_kwargs={}, response_metadata={}, id='f11e5482-03bf-47bb-94b5-5a6d0a35e1be'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_CA7Ayy2IPuQgztsMYG1LR6tt', 'function': {'arguments': '{"prompt":"Mumbai"}', 'name': 'get_city_details'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 60, 'total_tokens': 76, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-27b58312-4dcb-4729-9f10-6bff9e946018-0', tool_calls=[{'name': 'get_city_details', 'args': {'prompt': 'Mumbai'}, 'id': 'call_CA7Ayy2IPuQgztsMYG1LR6tt', 'type': 'tool_call'}], usage_metadata={'input_tokens': 60, 'output_tokens': 16, 'total_tokens': 76, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"url": "https://www.tripadvisor.com/Attractions-g304554-Activities-Mumbai_Maharashtra.html", "content": "Things to Do in Mumbai, India: See Tripadvisor\'s 641,172 traveler reviews and photos of Mumbai tourist attractions. Find what to do today, this weekend, or in December. We have reviews of the best places to see in Mumbai. Visit top-rated & must-see attractions."}, {"url": "https://www.tripsavvy.com/mumbai-attractions-and-places-to-visit-1539804", "content": "Top 12 Attractions and Places to Visit in Mumbai\\nOne Week in Mumbai: The Perfect Itinerary\\n15 Iconic Mumbai Religious Places to Visit\\nTop 18 Things to Do in Mumbai\\n48 Hours in Mumbai: The Perfect Itinerary\\n101 Places to Visit in Mumbai\\nThe 9 Top Parks in Mumbai\\n14 Best Mumbai Markets for Shopping and Sightseeing\\n15 Best Mumbai Tours to Really Get to Know the City\\n8 Cool Neighborhoods to Explore in Mumbai\\n11 Free Things to Do in India\\n20 Landmarks that Showcase Mumbai\'s Architecture\\nThe Best Time to Visit Mumbai\\nThe 9 Top Things to Do in Mumbai\'s Fort Neighborhood\\nEssential Guide to Walking Tours in India\\n10 Places to Marvel Over Mumbai\'s Unique Infrastructure\\n22 Caves in India for History, Adventure and Spirituality If these attractions aren\'t enough for you, check out these 101 Places to Visit in Mumbai!\\nGateway of India\\nVatsal Shah / TripSavvy\\nMumbai\'s most recognized monument, the Gateway of India, was constructed in 1924 to commemorate the visit of King George V and Queen Mary to the city. Some of the best are the Gothic-looking Chhatrapati Shivaji Maharaj Vastu Sangrahalaya Museum (formerly known as the Prince of Wales Museum), the Kala Ghoda art precinct, Chhatrapati Shivaji Maharaj Terminus (formerly Victoria Terminus) railway station, the Bombay High Court and the buildings of Horniman Circle in the Fort area. Juhu and Marine Drive Chowpatty Beaches\\nVatsal Shah / TripSavvy\\nAt the end of a tiring day of sightseeing, relax with the locals on the beaches of Juhu and Marine Drive, and watch the sunset. Mumbai Dabbawalas\\nDabbawala, meaning a person who carries a container, is the term given to the thousands of men responsible for transporting and delivering around 200,000 lunch boxes of freshly cooked food to the city\'s office workers every day."}, {"url": "https://www.tripsavvy.com/best-things-to-do-in-mumbai-5070679", "content": "Top 18 Things to Do in Mumbai\\nTop 12 Attractions and Places to Visit in Mumbai\\n9 Best Luxury Day Spas in Mumbai to Relax and Rejuvenate\\nOne Week in Mumbai: The Perfect Itinerary\\n48 Hours in Mumbai: The Perfect Itinerary\\nThe 9 Top Parks in Mumbai\\n8 Cool Neighborhoods to Explore in Mumbai\\n101 Places to Visit in Mumbai\\n20 Landmarks that Showcase Mumbai\'s Architecture\\nElep ...
# this is 04 response from respondstate_name='Maharashtra' state_capital='Mumbai' country_name='India' country_capital='New Delhi'

# %%
answer
# Out:
# CityDetails(state_name='Maharashtra', state_capital='Mumbai', country_name='India', country_capital='New Delhi')
